# %%
#numpy is a numerical library used for computing numerical calculations in python
import numpy as np
#pandas is a package used for data analysis
import pandas as pd
#matplotlib.pyplot is a plotting library used for 2D graphics in python programming language.
import matplotlib.pyplot as plt
#using %matplotlib inline, the output of plotting commands is displayed inline within frontends like the Jupyter notebook,
#directly below the code cell that produced it.
import os
# %matplotlib inline

# %%
##Loading the data
#checking the current working directory
#os. getcwd()
#reading the csv file
sales = pd.read_csv('sales_data.csv', parse_dates = ['Date'])
#printing the content of csv file
#print(sales) OR
sales
#printing the top 5 records using head()
#sales.head()
# Out:
#              Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26  November  2013            19     Youth (<25)
# 1      2015-11-26   26  November  2015            19     Youth (<25)
# 2      2014-03-23   23     March  2014            49  Adults (35-64)
# 3      2016-03-23   23     March  2016            49  Adults (35-64)
# 4      2014-05-15   15       May  2014            47  Adults (35-64)
# ...           ...  ...       ...   ...           ...             ...
# 113031 2016-04-12   12     April  2016            41  Adults (35-64)
# 113032 2014-04-02    2     April  2014            18     Youth (<25)
# 113033 2016-04-02    2     April  2016            18     Youth (<25)
# 113034 2014-03-04    4     March  2014            37  Adults (35-64)
# 113035 2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#shape gives the number of rows and columns in the data frame
sales.shape
# Out:
# (113036, 18)

# %%
#info() enlists the columns and their datatypes of this df
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
#Numerical analysis and Visualisations

##describe() gives the values related to stats- mean,median, mode..
sales.describe()

##describe for a particular column - Unit_Cost
sales['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
#computing mean for unit cost

sales['Unit_Cost'].mean()
# Out:
# 267.296365759581

# %%
#computing median for unit cost
sales['Unit_Cost'].median()
# Out:
# 9.0
